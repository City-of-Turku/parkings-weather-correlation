# %% [markdown]
# # Actual vs. Predictions
#
# ## Metrics
# | Topic                                      | Average Absolute Difference | Average Percentage Difference |
# |-------------------------------------------|------------------------------|-------------------------------|
# | Linear Regressor with Zone 1 Parkings     | 53.73                        | 58.75%                        |
# | MLP Regressor with Zone 1 Parkings        | 41.48                        | 25.68%                        |
# | MLP Regressor with Puutarhakatu 6         | 0.80                         | 28.84%                        |
# | MLP Regressor with Porthaninkatu 6        | 3.89                         | 47.96%                        |
#
#
# ## LinearRegressor with zone 1 parkings
# * Average Absolute Difference: 53.73
# * Average Percentage Difference: 58.75%
# ![image.png](attachment:image.png)
# The image shows that the linear regressor does not capture the Sundays.
# ## MLP Regressor with zone 1 parkings
# * Average Absolute Difference: 41.48
# * Average Percentage Difference: 25.68%
# ![image-2.png](attachment:image-2.png)
# ## MLP Regressor with Puutarhakatu 6 parkings
# * Average Absolute Difference: 0.8
# * Average Percentage Difference: 28.84%
# ![image-3.png](attachment:image-3.png)
# ## MLP Regressor with Porthaninkatu 6 parkings
# * Average Absolute Difference: 3.89
# * Average Percentage Difference: 47.96%
